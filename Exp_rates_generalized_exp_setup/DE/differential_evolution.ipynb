# %% [markdown]
# #### Dependencies

# %%
import numpy as np
import csv
import os
import sys  # Import the sys module
import time
from functools import partial
from multiprocessing import Pool, cpu_count
from scipy.optimize import differential_evolution

sys.path.append('..')
from dataset_reader import Traces_Dataset
from DE_obj_model import de_obj_model   
from exp_hh_model import HH_model_exp

# %% [markdown]
# #### Read test dataset

# %%
dataset = Traces_Dataset('../dataset_test.csv')

params = dataset.params.numpy()
current_traces = dataset.current_traces.numpy()
time_traces = dataset.time_traces.numpy()

sample = 32
prestep_V_2d = dataset.prestep_V[sample].numpy().reshape(-1,1)
step_Vs_2d = dataset.step_Vs[sample].numpy().reshape(-1,1)
t = time_traces[sample]

target_traces = current_traces[sample]
target_params = params[sample]

# %%
# sim setup for obj evaluation model
sim_setup_2d = {'prestep_V': prestep_V_2d, 'step_Vs': step_Vs_2d, 't': t}
# sim_setup_2d
# model = de_obj_model(target_params, sim_setup_2d)

# %%
# sim_traces = model.simulation()
# sim_traces.shape

# %% [markdown]
# #### Plotting function for trail, target, and real data

# %%
def plot_trail_target_real(sim_setup_1d, t, sim_traces, target_traces, target_params): 
    '''
    sim_setup_1d is the exp setup for hh model, all default as in hh class
    t is the target time traces from generated dataset
    sim_traces is the generated during searching stage
    target_traces is the target current traces from the generated dataset
    target_params is the target params from the generated dataset, dict
    '''
    # compare samples and simulations using sample params
    hh_model = HH_model_exp(target_params, sim_setup_1d)
    current_traces_sim = hh_model.simulation()

    colors = ['blue', 'red', 'green', 'purple', 'orange', 'yellow', 'cyan', 'magenta', 'brown', 'gray', 'black']

    for step in range(t.shape[0]): 
        plt.plot(t[step], sim_traces[step], linestyle='-', color=colors[step])
        plt.plot(t[step], target_traces[step], linestyle=':', color=colors[step])
        plt.plot(sim_setup_1d['t'], current_traces_sim[step], linestyle='--', color=colors[step])
    plt.legend()
    plt.title(f"prestep_V: {sim_setup_1d['prestep_V']}; step_V1: {sim_setup_1d['step_Vs'][0]}")

# %%
# sim setup for plotting real data
sim_setup_1d = {'prestep_V': np.squeeze(prestep_V_2d), 'step_Vs': np.squeeze(step_Vs_2d), 't': np.arange(0.0, 6.0, 0.01)}
target_params_dict = {'p': target_params[0], 'g_max': target_params[1], 'E_rev': target_params[2], 'a_m': target_params[3], 'b_m': target_params[4], 'delta_m': target_params[5], 's_m': target_params[6]}
plot_trail_target_real(sim_setup_1d, t, sim_traces, target_traces, target_params_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       2 sim_setup_1d = {'prestep_V': np.squeeze(prestep_V_2d), 'step_Vs': np.squeeze(step_Vs_2d), 't': np.arange(0.0, 6.0, 0.01)}
#       3 target_params_dict = {'p': target_params[0], 'g_max': target_params[1], 'E_rev': target_params[2], 'a_m': target_params[3], 'b_m': target_params[4], 'delta_m': target_params[5], 's_m': target_params[6]}
# ----> 4 plot_trail_target_real(sim_setup_1d, t, sim_traces, target_traces, target_params_dict)
#
# NameError: name 'sim_traces' is not defined

# %% [markdown]
# #### Define obj function

# %%
def obj(x, *args): 
    '''
    x: a 1-D array of the variables for the obj function (the parameters we are estimating)
    args: a tupleo f additional fixed parameters (prestep_V, step_V0, time_traces)
    *args=(sim_setup_2d, target_current_trances)
    '''
    trail_model = de_obj_model(x, args[0])
    trail_traces = trail_model.simulation()
    # print(trail_traces[1])
    target_model = de_obj_model(args[1], args[0])
    target_traces = target_model.simulation()
    # print(target_traces[1]) 

    fit = np.sum(np.square(trail_traces - target_traces))
    # relative_error = fit/np.sum(np.square(target_traces))
    
    return fit

# %%
fitness = obj(params[0], *(sim_setup_2d, target_params))
print(fitness)
# Out:
# 1903430900.0

# %% [markdown]
# #### Define bounds

# %%
# these bounds are from the distribution of the params in the dataset used for NN training
params_searching_bounds = {
    'p': (1, 4),
    'g_max': (100, 140), 
    'E_rev': (-100, -60), 
    'a_m': (0, 100), 
    'b_m': (0, 100), 
    'delta_m': (0, 1), 
    's_m': (-100, 0)
}
bounds = [params_searching_bounds['p'], params_searching_bounds['g_max'], params_searching_bounds['E_rev'], params_searching_bounds['a_m'], params_searching_bounds['b_m'], params_searching_bounds['delta_m'], params_searching_bounds['s_m']]

# %%
# def callback_function(xk, convergence):
#     callback_function.iteration += 1
#     print("Iteration:", callback_function.iteration)
#     print("Solution:", xk)
#     print("Objective value:", obj(xk, sim_setup_2d, target_params))
#     print("------------------------")
# callback_function.iteration = 0  # Initialize the iteration counter

# %%
from scipy.optimize import differential_evolution

result = differential_evolution(obj, bounds, args=(sim_setup_2d, target_params), strategy='best1bin', popsize=21, mutation=(0.1,0.9), recombination=0.9, seed=42, maxiter=1000, tol=-1, disp=True)#, callback=callback_function)
# Out:
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: overflow encountered in exp
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# differential_evolution step 1: f(x)= 1.8209e+08
# differential_evolution step 2: f(x)= 1.08321e+08
# differential_evolution step 3: f(x)= 6.2799e+07
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: invalid value encountered in divide
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: overflow encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# differential_evolution step 4: f(x)= 6.2799e+07
# differential_evolution step 5: f(x)= 2.72009e+07
# differential_evolution step 6: f(x)= 2.72009e+07
# differential_evolution step 7: f(x)= 2.67437e+07
# differential_evolution step 8: f(x)= 2.67437e+07
# differential_evolution step 9: f(x)= 2.67437e+07
# differential_evolution step 10: f(x)= 2.5413e+07
# differential_evolution step 11: f(x)= 2.01641e+07
# differential_evolution step 12: f(x)= 1.93988e+07
# differential_evolution step 13: f(x)= 1.88105e+07
# differential_evolution step 14: f(x)= 1.88064e+07
# differential_evolution step 15: f(x)= 1.86614e+07
# differential_evolution step 16: f(x)= 1.80321e+07
# differential_evolution step 17: f(x)= 1.73988e+07
# differential_evolution step 18: f(x)= 1.61516e+07
# differential_evolution step 19: f(x)= 1.40627e+07
# differential_evolution step 20: f(x)= 1.06839e+07
# differential_evolution step 21: f(x)= 9.93744e+06
# differential_evolution step 22: f(x)= 9.88508e+06
# differential_evolution step 23: f(x)= 9.3476e+06
# differential_evolution step 24: f(x)= 8.99319e+06
# differential_evolution step 25: f(x)= 7.82106e+06
# differential_evolution step 26: f(x)= 4.42826e+06
# differential_evolution step 27: f(x)= 4.01193e+06
# differential_evolution step 28: f(x)= 3.7671e+06
# differential_evolution step 29: f(x)= 3.53883e+06
# differential_evolution step 30: f(x)= 3.16761e+06
# differential_evolution step 31: f(x)= 2.02023e+06
# differential_evolution step 32: f(x)= 992317
# differential_evolution step 33: f(x)= 857304
# differential_evolution step 34: f(x)= 829067
# differential_evolution step 35: f(x)= 659744
# differential_evolution step 36: f(x)= 497442
# differential_evolution step 37: f(x)= 497442
# differential_evolution step 38: f(x)= 497442
# differential_evolution step 39: f(x)= 486046
# differential_evolution step 40: f(x)= 416727
# differential_evolution step 41: f(x)= 366986
# differential_evolution step 42: f(x)= 28795.8
# differential_evolution step 43: f(x)= 7200.9
# differential_evolution step 44: f(x)= 3081.95
# differential_evolution step 45: f(x)= 3055.06
# differential_evolution step 46: f(x)= 649.149
# differential_evolution step 47: f(x)= 649.149
# differential_evolution step 48: f(x)= 649.149
# differential_evolution step 49: f(x)= 649.149
# differential_evolution step 50: f(x)= 649.149
# differential_evolution step 51: f(x)= 649.149
# differential_evolution step 52: f(x)= 489.953
# differential_evolution step 53: f(x)= 410.55
# differential_evolution step 54: f(x)= 410.55
# differential_evolution step 55: f(x)= 387.215
# differential_evolution step 56: f(x)= 329.961
# differential_evolution step 57: f(x)= 243.526
# differential_evolution step 58: f(x)= 176.982
# differential_evolution step 59: f(x)= 176.489
# differential_evolution step 60: f(x)= 171.212
# differential_evolution step 61: f(x)= 171.212
# differential_evolution step 62: f(x)= 149.275
# differential_evolution step 63: f(x)= 103.44
# differential_evolution step 64: f(x)= 73.3314
# differential_evolution step 65: f(x)= 56.2101
# differential_evolution step 66: f(x)= 43.4442
# differential_evolution step 67: f(x)= 29.5203
# differential_evolution step 68: f(x)= 20.1721
# differential_evolution step 69: f(x)= 12.0101
# differential_evolution step 70: f(x)= 8.1009
# differential_evolution step 71: f(x)= 6.68809
# differential_evolution step 72: f(x)= 5.93825
# differential_evolution step 73: f(x)= 4.86456
# differential_evolution step 74: f(x)= 3.92042
# differential_evolution step 75: f(x)= 1.87832
# differential_evolution step 76: f(x)= 1.1407
# differential_evolution step 77: f(x)= 0.965663
# differential_evolution step 78: f(x)= 0.681889
# differential_evolution step 79: f(x)= 0.549111
# differential_evolution step 80: f(x)= 0.420972
# differential_evolution step 81: f(x)= 0.337987
# differential_evolution step 82: f(x)= 0.243598
# differential_evolution step 83: f(x)= 0.186672
# differential_evolution step 84: f(x)= 0.095742
# differential_evolution step 85: f(x)= 0.0164527
# differential_evolution step 86: f(x)= 0.0164527
# differential_evolution step 87: f(x)= 0.00767189
# differential_evolution step 88: f(x)= 0.00683159
# differential_evolution step 89: f(x)= 0.00665286
# differential_evolution step 90: f(x)= 0.00665286
# differential_evolution step 91: f(x)= 0.00665286
# differential_evolution step 92: f(x)= 0.00581979
# differential_evolution step 93: f(x)= 0.00581979
# differential_evolution step 94: f(x)= 0.00581979
# differential_evolution step 95: f(x)= 0.00581979
# differential_evolution step 96: f(x)= 0.00581979
# differential_evolution step 97: f(x)= 0.00581979
# differential_evolution step 98: f(x)= 0.00581979
# differential_evolution step 99: f(x)= 0.00581979
# differential_evolution step 100: f(x)= 0.00581979
# differential_evolution step 101: f(x)= 0.00581979
# differential_evolution step 102: f(x)= 0.00581979
# differential_evolution step 103: f(x)= 0.00581146
# differential_evolution step 104: f(x)= 0.00567678
# differential_evolution step 105: f(x)= 0.00567678
# differential_evolution step 106: f(x)= 0.00567678
# differential_evolution step 107: f(x)= 0.00567678
# differential_evolution step 108: f(x)= 0.00561107
# differential_evolution step 109: f(x)= 0.00553531
# differential_evolution step 110: f(x)= 0.00553531
# differential_evolution step 111: f(x)= 0.00553531
# differential_evolution step 112: f(x)= 0.00553531
# differential_evolution step 113: f(x)= 0.00553531
# differential_evolution step 114: f(x)= 0.00553531
# differential_evolution step 115: f(x)= 0.00553531
# differential_evolution step 116: f(x)= 0.00551581
# differential_evolution step 117: f(x)= 0.00551581
# differential_evolution step 118: f(x)= 0.00541987
# differential_evolution step 119: f(x)= 0.00541987
# differential_evolution step 120: f(x)= 0.00541987
# differential_evolution step 121: f(x)= 0.00540949
# differential_evolution step 122: f(x)= 0.00540949
# differential_evolution step 123: f(x)= 0.00540564
# differential_evolution step 124: f(x)= 0.00537219
# differential_evolution step 125: f(x)= 0.0053134
# differential_evolution step 126: f(x)= 0.00527051
# differential_evolution step 127: f(x)= 0.00525513
# differential_evolution step 128: f(x)= 0.00524459
# differential_evolution step 129: f(x)= 0.00524183
# differential_evolution step 130: f(x)= 0.00522789
# differential_evolution step 131: f(x)= 0.00520064
# differential_evolution step 132: f(x)= 0.00516221
# differential_evolution step 133: f(x)= 0.00510965
# differential_evolution step 134: f(x)= 0.00510832
# differential_evolution step 135: f(x)= 0.00510814
# differential_evolution step 136: f(x)= 0.00510809
# differential_evolution step 137: f(x)= 0.00510809
# differential_evolution step 138: f(x)= 0.00510809
# differential_evolution step 139: f(x)= 0.00510807
# differential_evolution step 140: f(x)= 0.00510807
# differential_evolution step 141: f(x)= 0.00510807
# differential_evolution step 142: f(x)= 0.00510807
# differential_evolution step 143: f(x)= 0.00510807
# differential_evolution step 144: f(x)= 0.00510807
# differential_evolution step 145: f(x)= 0.00510807
# differential_evolution step 146: f(x)= 0.00510807
# differential_evolution step 147: f(x)= 0.00510807
# differential_evolution step 148: f(x)= 0.00510807
# differential_evolution step 149: f(x)= 0.00510807
# differential_evolution step 150: f(x)= 0.00510807
# differential_evolution step 151: f(x)= 0.00510807
# differential_evolution step 152: f(x)= 0.00510807
# differential_evolution step 153: f(x)= 0.00510807
# differential_evolution step 154: f(x)= 0.00510807
# differential_evolution step 155: f(x)= 0.00510807
# differential_evolution step 156: f(x)= 0.00510807
# differential_evolution step 157: f(x)= 0.00510807
# differential_evolution step 158: f(x)= 0.00510807
# differential_evolution step 159: f(x)= 0.00510807
# differential_evolution step 160: f(x)= 0.00510807
# differential_evolution step 161: f(x)= 0.00510807
# differential_evolution step 162: f(x)= 0.00510807
# differential_evolution step 163: f(x)= 0.00510807
# differential_evolution step 164: f(x)= 0.00510807
# differential_evolution step 165: f(x)= 0.00510807
# differential_evolution step 166: f(x)= 0.00510807
# differential_evolution step 167: f(x)= 0.00510807
# differential_evolution step 168: f(x)= 0.00510807
# differential_evolution step 169: f(x)= 0.00510807
# differential_evolution step 170: f(x)= 0.00510807
# differential_evolution step 171: f(x)= 0.00510807
# differential_evolution step 172: f(x)= 0.00510807
# differential_evolution step 173: f(x)= 0.00510807
# differential_evolution step 174: f(x)= 0.00510807
# differential_evolution step 175: f(x)= 0.00510807
# differential_evolution step 176: f(x)= 0.00510807
# differential_evolution step 177: f(x)= 0.00510807
# differential_evolution step 178: f(x)= 0.00510807
# differential_evolution step 179: f(x)= 0.00510807
# differential_evolution step 180: f(x)= 0.00510807
# differential_evolution step 181: f(x)= 0.00510807
# differential_evolution step 182: f(x)= 0.00510807
# differential_evolution step 183: f(x)= 0.00510807
# differential_evolution step 184: f(x)= 0.00510807
# differential_evolution step 185: f(x)= 0.00510807
# differential_evolution step 186: f(x)= 0.00510807
# differential_evolution step 187: f(x)= 0.00510807
# differential_evolution step 188: f(x)= 0.00510807
# differential_evolution step 189: f(x)= 0.00510807
# differential_evolution step 190: f(x)= 0.00510807
# differential_evolution step 191: f(x)= 0.00510807
# differential_evolution step 192: f(x)= 0.00510807
# differential_evolution step 193: f(x)= 0.00510807
# differential_evolution step 194: f(x)= 0.00510807
# differential_evolution step 195: f(x)= 0.00510807
# differential_evolution step 196: f(x)= 0.00510807
# differential_evolution step 197: f(x)= 0.00510807
# differential_evolution step 198: f(x)= 0.00510807
# differential_evolution step 199: f(x)= 0.00510807
# differential_evolution step 200: f(x)= 0.00510807
# differential_evolution step 201: f(x)= 0.00510807
# differential_evolution step 202: f(x)= 0.00510807
# differential_evolution step 203: f(x)= 0.00510807
# differential_evolution step 204: f(x)= 0.00510807
# differential_evolution step 205: f(x)= 0.00510807
# differential_evolution step 206: f(x)= 0.00510807
# differential_evolution step 207: f(x)= 0.00510807
# differential_evolution step 208: f(x)= 0.00510807
# differential_evolution step 209: f(x)= 0.00510807
# differential_evolution step 210: f(x)= 0.00510807
# differential_evolution step 211: f(x)= 0.00510807
# differential_evolution step 212: f(x)= 0.00510807
# differential_evolution step 213: f(x)= 0.00510807
# differential_evolution step 214: f(x)= 0.00510807
# differential_evolution step 215: f(x)= 0.00510807
# differential_evolution step 216: f(x)= 0.00510807
# differential_evolution step 217: f(x)= 0.00510807
# differential_evolution step 218: f(x)= 0.00510807
# differential_evolution step 219: f(x)= 0.00510807
# differential_evolution step 220: f(x)= 0.00510807
# differential_evolution step 221: f(x)= 0.00510807
# differential_evolution step 222: f(x)= 0.00510807
# differential_evolution step 223: f(x)= 0.00510807
# differential_evolution step 224: f(x)= 0.00510807
# differential_evolution step 225: f(x)= 0.00510807
# differential_evolution step 226: f(x)= 0.00510807
# differential_evolution step 227: f(x)= 0.00510807
# differential_evolution step 228: f(x)= 0.00510807
# differential_evolution step 229: f(x)= 0.00510807
# differential_evolution step 230: f(x)= 0.00510807
# differential_evolution step 231: f(x)= 0.00510807
# differential_evolution step 232: f(x)= 0.00510807
# differential_evolution step 233: f(x)= 0.00510807
# differential_evolution step 234: f(x)= 0.00510807
# differential_evolution step 235: f(x)= 0.00510807
# differential_evolution step 236: f(x)= 0.00510807
# differential_evolution step 237: f(x)= 0.00510807
# differential_evolution step 238: f(x)= 0.00510807
# differential_evolution step 239: f(x)= 0.00510807
# differential_evolution step 240: f(x)= 0.00510807
# differential_evolution step 241: f(x)= 0.00510807
# differential_evolution step 242: f(x)= 0.00510807
# differential_evolution step 243: f(x)= 0.00510807
# differential_evolution step 244: f(x)= 0.00510807
# differential_evolution step 245: f(x)= 0.00510807
# differential_evolution step 246: f(x)= 0.00510807
# differential_evolution step 247: f(x)= 0.00510807
# differential_evolution step 248: f(x)= 0.00510807
# differential_evolution step 249: f(x)= 0.00510807
# differential_evolution step 250: f(x)= 0.00510807
# differential_evolution step 251: f(x)= 0.00510807
# differential_evolution step 252: f(x)= 0.00510807
# differential_evolution step 253: f(x)= 0.00510807
# differential_evolution step 254: f(x)= 0.00510807
# differential_evolution step 255: f(x)= 0.00510807
# differential_evolution step 256: f(x)= 0.00510807
# differential_evolution step 257: f(x)= 0.00510807
# differential_evolution step 258: f(x)= 0.00510807
# differential_evolution step 259: f(x)= 0.00510807
# differential_evolution step 260: f(x)= 0.00510807
# differential_evolution step 261: f(x)= 0.00510807

# %%
target_params, result.x

# %%
(target_params - result.x) ** 2

# %%
np.mean((target_params - result.x) ** 2)

# %%
result.x
# Out:
# array([  2.99999976, 129.03803142, -64.20609941,   1.25369308,
#         90.05368963,   0.31965496,  -9.59330794])

# %%
result
# Out:
#  message: Maximum number of iterations has been exceeded.
#  success: False
#      fun: 26.620414408339457
#        x: [ 3.295e+00  1.067e+02 -7.884e+01  4.578e+00  1.433e+01
#             1.639e-01 -4.363e+01]
#      nit: 300
#     nfev: 31797
#      jac: [ 4.463e-02 -3.375e-04  3.823e-04  0.000e+00  0.000e+00
#             0.000e+00  0.000e+00]

# %% [markdown]
# ### test on all samples

# %%
dataset = Traces_Dataset('../dataset_test.csv')

params = dataset.params.numpy()
current_traces = dataset.current_traces.numpy()
time_traces = dataset.time_traces.numpy()

prestep_V_vec = dataset.prestep_V.numpy()
step_Vs_vec = dataset.step_Vs.numpy()

# %%
def obj(x, *args): 
    '''
    x: a 1-D array of the variables for the obj function (the parameters we are estimating)
    *args=(sim_setup_2d, target_current_trances)
    '''
    trail_model = de_obj_model(x, args[0])
    trail_traces = trail_model.simulation()
    # print(trail_traces[1])
    target_model = de_obj_model(args[1], args[0])
    target_traces = target_model.simulation()
    # print(target_traces[1]) 

    fit = np.sum(np.square(trail_traces - target_traces))
    # relative_error = fit/np.sum(np.square(target_traces))
    
    return fit

# %%
# these bounds are from the distribution of the params in the dataset used for NN training
params_searching_bounds = {
    'p': (1, 4),
    'g_max': (100, 140), 
    'E_rev': (-100, -60), 
    'a_m': (0, 100), 
    'b_m': (0, 100), 
    'delta_m': (0, 1), 
    's_m': (-100, 0)
}
bounds = [params_searching_bounds['p'], params_searching_bounds['g_max'], params_searching_bounds['E_rev'], params_searching_bounds['a_m'], params_searching_bounds['b_m'], params_searching_bounds['delta_m'], params_searching_bounds['s_m']]

# %%
mse_list = []
time_list = []

for sample in range(10):
    print(f'{sample}: \n')               
    prestep_V_2d = prestep_V_vec[sample].reshape(-1,1)
    step_Vs_2d = step_Vs_vec[sample].reshape(-1,1)
    t = time_traces[sample]

    # prestep_V_2d = dataset.prestep_V[sample].numpy().reshape(-1,1)
    # step_Vs_2d = dataset.step_Vs[sample].numpy().reshape(-1,1)
    # t = time_traces[sample]

    # target_traces = current_traces[sample]
    target_params = params[sample]

    # sim setup for obj evaluation model
    sim_setup_2d = {'prestep_V': prestep_V_2d, 'step_Vs': step_Vs_2d, 't': t}   

    start_time = time.time()
    result = differential_evolution(obj, bounds, args=(sim_setup_2d, target_params), seed=42, maxiter=300, disp=True)
    end_time = time.time()

    print(target_params, result.x)

    mse = (target_params - result.x) ** 2
    mse_list.append(mse)
    elapsed_time = end_time - start_time
    time_list.append(elapsed_time)

mse_mat = np.vstack(mse_list)
time_mat = np.array(time_list).reshape(-1, 1)

mse_overall_avg = np.mean(mse_mat)
mse_overall_std = np.std(np.mean(mse_mat, axis=1))
time_overall_avg = np.mean(time_mat)
time_overall_std = np.std(time_mat)

# %%
mse_overall_avg
# Out:
# 127.9836217441734

# %%
target_params, result.x
# Out:
# (array([  4.       , 118.27517  , -71.81706  ,   2.0534372,  13.061292 ,
#           0.1570644, -11.075991 ], dtype=float32),
#  array([  3.99999708, 118.27580194, -71.81624795,   2.05343767,
#          13.06131683,   0.1570641 , -11.07597521]))

# %% [markdown]
# ### Hyperparameter Tuning

# %%
dataset = Traces_Dataset('../dataset_test.csv')

params = dataset.params.numpy()
# current_traces = dataset.current_traces.numpy()
time_traces = dataset.time_traces.numpy()

prestep_V_vec = dataset.prestep_V.numpy()
step_Vs_vec = dataset.step_Vs.numpy()

# %%
def obj(x, *args): 
    '''
    x: a 1-D array of the variables for the obj function (the parameters we are estimating)
    *args=(sim_setup_2d, target_current_trances)
    '''
    trail_model = de_obj_model(x, args[0])
    trail_traces = trail_model.simulation()
    # print(trail_traces[1])
    target_model = de_obj_model(args[1], args[0])
    target_traces = target_model.simulation()
    # print(target_traces[1]) 

    fit = np.sum(np.square(trail_traces - target_traces))
    # relative_error = fit/np.sum(np.square(target_traces))
    
    return fit

# %%
# these bounds are from the distribution of the params in the dataset used for NN training
params_searching_bounds = {
    'p': (1, 4),
    'g_max': (100, 140), 
    'E_rev': (-100, -60), 
    'a_m': (0, 100), 
    'b_m': (0, 100), 
    'delta_m': (0, 1), 
    's_m': (-100, 0)
}
bounds = [params_searching_bounds['p'], params_searching_bounds['g_max'], params_searching_bounds['E_rev'], params_searching_bounds['a_m'], params_searching_bounds['b_m'], params_searching_bounds['delta_m'], params_searching_bounds['s_m']]

# %%
hyperparameters_grid = {
    'strategy': ['best1bin', 'best1exp', 'rand1exp', 'rand1exp', 
                'rand2bin', 'rand2exp', 'best2bin', 'best2exp',
                'randtobest1bin', 'randtobest1exp',
                'currenttobest1bin', 'currenttobest1exp'],
    'popsize': [14,21,28,35,42,49,56,63,70],  # Example popsize hyperparameter
    'mutation': [(0.1, 0.9)],  # Example mutation hyperparameter
    'recombination': [0.9],  # Example recombination hyperparameter
    'init': ['latinhypercube'],  # Example init hyperparameter
}

# %%
#############################################################################
#using single samples to tune hyperparameters################################
#############################################################################
sample = 32

csv_filename = f'de_experiment_results_{sample}.csv'
# Define the headers for the CSV file
csv_headers = ['Strategy', 'Popsize', 'Mutation', 'Recombination', 'Init', 'MSE Overall', 'Elapsed Time']

# Check if the CSV file exists; if not, create and write the headers
if not os.path.exists(csv_filename):
    with open(csv_filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(csv_headers)

with open(csv_filename, mode='a', newline='') as file:
    writer = csv.writer(file)
    for strategy in hyperparameters_grid['strategy']:
        for popsize in hyperparameters_grid['popsize']:
            for mutation in hyperparameters_grid['mutation']:
                for recombination in hyperparameters_grid['recombination']:
                    for init in hyperparameters_grid['init']:

                        prestep_V_2d = prestep_V_vec[sample].reshape(-1,1)
                        step_Vs_2d = step_Vs_vec[sample].reshape(-1,1)
                        t = time_traces[sample]
                        # target_traces = current_traces[sample]
                        target_params = params[sample]

                        # sim setup for obj evaluation model
                        sim_setup_2d = {'prestep_V': prestep_V_2d, 'step_Vs': step_Vs_2d, 't': t}   

                        start_time = time.time()
                        result = differential_evolution(obj, bounds, args=(sim_setup_2d, target_params), strategy=strategy, popsize=popsize, mutation=mutation, recombination=recombination, init=init, seed=42, maxiter=1000, tol=-1)
                        end_time = time.time()
                    
                        mse = (target_params - result.x) ** 2
                        elapsed_time = end_time - start_time

                        mse_overall = np.mean(mse)
                        print(mse_overall)
                        
                        writer.writerow([strategy, popsize, mutation, recombination, init, mse_overall, elapsed_time])
# Out:
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: overflow encountered in exp
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: invalid value encountered in divide
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# 5.790645656876622e-06
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: overflow encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in log
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: invalid value encountered in multiply
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# 0.00011047152607005798
# 0.35020603850826604
# 1.9287171293266236e-07
# 14.532495995561451
# 2.765022975910945e-06
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# 2.3395979887303018e-07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 34
#      31 sim_setup_2d = {'prestep_V': prestep_V_2d, 'step_Vs': step_Vs_2d, 't': t}
#      33 start_time = time.time()
# ---> 34 result = differential_evolution(obj, bounds, args=(sim_setup_2d, target_params), strategy=strategy, popsize=popsize, mutation=mutation, recombination=recombination, init=init, seed=42, maxiter=1000, tol=-1)
#      35 end_time = time.time()
#      37 mse = (target_params - result.x) ** 2
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:402, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     385 # using a context manager means that any created Pool objects are
#     386 # cleared up.
#     387 with DifferentialEvolutionSolver(func, bounds, args=args,
#     388                                  strategy=strategy,
#     389                                  maxiter=maxiter,
#    (...)
#     400                                  integrality=integrality,
#     401                                  vectorized=vectorized) as solver:
# --> 402     ret = solver.solve()
#     404 return ret
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:1022, in DifferentialEvolutionSolver.solve(self)
#    1019 for nit in range(1, self.maxiter + 1):
#    1020     # evolve the population by a generation
#    1021     try:
# -> 1022         next(self)
#    1023     except StopIteration:
#    1024         warning_flag = True
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:1409, in DifferentialEvolutionSolver.__next__(self)
#    1407     feasible = True
#    1408     cv = np.atleast_2d([0.])
# -> 1409     energy = self.func(parameters)
#    1410     self._nfev += 1
#    1412 # compare trial and population member
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/_lib/_util.py:360, in _FunctionWrapper.__call__(self, x)
#     359 def __call__(self, x):
# --> 360     return self.f(x, *self.args)
#
# Cell In[71], line 10, in obj(x, *args)
#       8 # print(trail_traces[1])
#       9 target_model = de_obj_model(args[1], args[0])
# ---> 10 target_traces = target_model.simulation()
#      11 # print(target_traces[1])
#      13 fit = np.sum(np.square(trail_traces - target_traces))
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:75, in de_obj_model.simulation(self)
#      69 '''
#      70 simulation only contains fixed prestep potential and a number of step potentials, covered in the sim_setup dict
#      71 generate current traces according to the setup
#      72 '''
#      74 # self.current_traces = np.array([self.find_I(v) for v in self.step_Vs])
# ---> 75 self.current_traces = self.find_I(self.step_Vs)
#      76 ##################################
#      77 #####setting nan values to be 0????????
#      78 self.current_traces[np.isnan(self.current_traces)] = 0
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:66, in de_obj_model.find_I(self, V)
#      65 def find_I(self, V):
# ---> 66     return np.full(self.m(self.step_Vs).shape, self.g_max) * np.power(self.m(V), np.full(self.m(self.step_Vs).shape, self.p)) * (V - np.full(self.m(self.step_Vs).shape, self.E_rev))
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63, in de_obj_model.m(self, V)
#      58 def m(self, V):
#      59     '''
#      60     Find the activation/inactivation variable analytically with I.C. x(0) = initial_cond
#      61     This only stands with fixed prestep potential simulation setup!
#      62     '''
# ---> 63     return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42, in de_obj_model.tau_m(self, V)
#      37 '''
#      38 Find the time constant curve at a fixed V, it governs the rate at which x approaches to the steady state at a fixed V.
#      39 V: membrane voltage
#      40 '''
#      41 tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# ---> 42 return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
#
# KeyboardInterrupt:

# %%
#############################################################################
#using multiple samples to tune hyperparameters##############################
#############################################################################
csv_filename = "de_experiment_results_try_2.csv"
# Define the headers for the CSV file
csv_headers = ['Strategy', 'Popsize', 'Mutation', 'Recombination', 'Init', 'MSE Overall', 'Elapsed Time']

# Check if the CSV file exists; if not, create and write the headers
if not os.path.exists(csv_filename):
    with open(csv_filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(csv_headers)


def process_sample(sample, strategy, popsize, mutation, recombination, init):
    prestep_V_2d = prestep_V_vec[sample]
    step_Vs_2d = prestep_V_vec[sample]
    t = time_traces[sample]
    # target_traces = current_traces[sample]
    target_params = params[sample]

    # sim setup for obj evaluation model
    sim_setup_2d = {'prestep_V': prestep_V_2d, 'step_Vs': step_Vs_2d, 't': t}   

    start_time = time.time()
    result = differential_evolution(obj, bounds, args=(sim_setup_2d, target_params), strategy=strategy, popsize=popsize, mutation=mutation, recombination=recombination, init=init, seed=42, maxiter=1000, tol=-1)
    end_time = time.time()
    
    mse = (target_params - result.x) ** 2
    elapsed_time = end_time - start_time
    return sample, mse, elapsed_time

if __name__ == '__main__':
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        # pool = Pool()  # Creates a pool of processes
        num_processes = cpu_count()
        
        # Create the pool with the specified number of processes
        pool = Pool(processes=num_processes)  
        
        for strategy in hyperparameters_grid['strategy']:
            for popsize in hyperparameters_grid['popsize']:
                for mutation in hyperparameters_grid['mutation']:
                    for recombination in hyperparameters_grid['recombination']:
                        for init in hyperparameters_grid['init']:
                            # Use partial to fix hyperparameters for the current loop iteration
                            process_func = partial(process_sample, strategy=strategy, popsize=popsize, mutation=mutation, recombination=recombination, init=init)
                            
                            # Map the process function to the sample range using the multiprocessing pool
                            results = pool.map(process_func, range(1000))

                            mse_list = []
                            time_list = []
                            for result in results:
                                sample, mse, elapsed_time = result
                                mse_list.append(mse)
                                time_list.append(elapsed_time)

                            mse_mat = np.vstack(mse_list)
                            time_mat = np.array(time_list).reshape(-1, 1)

                            mse_overall_avg = np.mean(mse_mat)
                            mse_overall_std = np.std(np.mean(mse_mat, axis=1))
                            time_overall_avg = np.mean(time_mat)
                            time_overall_std = np.std(time_mat)
                            
                            writer.writerow([strategy, popsize, mutation, recombination, init, mse_overall_avg, mse_overall_std, time_overall_avg, time_overall_std])
        
        pool.close()  # Close the pool
        pool.join()   # Wait for all processes to finish before exiting
# Out:
# Process ForkPoolWorker-61:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-62:
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-63:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-46:
# Process ForkPoolWorker-18:
# Traceback (most recent call last):
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-43:
# Traceback (most recent call last):
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-21:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-64:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-34:
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-20:
# Traceback (most recent call last):
# Process ForkPoolWorker-17:
# Traceback (most recent call last):
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-24:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-8:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-26:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-40:
# Traceback (most recent call last):
# Process ForkPoolWorker-15:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-9:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-28:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#
# KeyboardInterrupt
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-6:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-42:
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 366, in get
#     res = self._reader.recv_bytes()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
with open(csv_filename, mode='a', newline='') as file:
    writer = csv.writer(file)
    for strategy in hyperparameters_grid['strategy']:
        for popsize in hyperparameters_grid['popsize']:
            for mutation in hyperparameters_grid['mutation']:
                for recombination in hyperparameters_grid['recombination']:
                    for init in hyperparameters_grid['init']:
                        mse_list = []
                        time_list = []
                        for sample in range(3): 
                            
                            prestep_V_2d = prestep_V_2d_vec[sample]
                            step_Vs_2d = step_Vs_2d_vec[sample]
                            t = time_traces[sample]
                            # target_traces = current_traces[sample]
                            target_params = params[sample]

                            # sim setup for obj evaluation model
                            sim_setup_2d = {'prestep_V': prestep_V_2d, 'step_Vs': step_Vs_2d, 't': t}   

                            start_time = time.time()
                            result = differential_evolution(obj, bounds, args=(sim_setup_2d, target_params), strategy=strategy, popsize=popsize, mutation=mutation, recombination=recombination, init=init, seed=42, maxiter=2)
                            end_time = time.time()
                        
                            mse = (target_params - result.x) ** 2
                            mse_list.append(mse)
                            elapsed_time = end_time - start_time
                            time_list.append(elapsed_time)

                        mse_mat = np.vstack(mse_list)
                        time_mat = np.array(time_list).reshape(-1, 1)

                        mse_overall_avg = np.mean(mse_mat)
                        mse_overall_std = np.std(np.mean(mse_mat, axis=1))
                        time_overall_avg = np.mean(time_mat)
                        time_overall_std = np.std(time_mat)
                        
                        writer.writerow([strategy, popsize, mutation, recombination, init, sample, mse_overall_avg, mse_overall_std, time_overall_avg, time_overall_std])
# Out:
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 22
#      19 sim_setup_2d = {'prestep_V': prestep_V_2d, 'step_Vs': step_Vs_2d, 't': t}
#      21 start_time = time.time()
# ---> 22 result = differential_evolution(obj, bounds, args=(sim_setup_2d, target_params), strategy=strategy, popsize=popsize, mutation=mutation, recombination=recombination, init=init, seed=42, maxiter=2)
#      23 end_time = time.time()
#      25 mse = (target_params - result.x) ** 2
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:402, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     385 # using a context manager means that any created Pool objects are
#     386 # cleared up.
#     387 with DifferentialEvolutionSolver(func, bounds, args=args,
#     388                                  strategy=strategy,
#     389                                  maxiter=maxiter,
#    (...)
#     400                                  integrality=integrality,
#     401                                  vectorized=vectorized) as solver:
# --> 402     ret = solver.solve()
#     404 return ret
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:1022, in DifferentialEvolutionSolver.solve(self)
#    1019 for nit in range(1, self.maxiter + 1):
#    1020     # evolve the population by a generation
#    1021     try:
# -> 1022         next(self)
#    1023     except StopIteration:
#    1024         warning_flag = True
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:1409, in DifferentialEvolutionSolver.__next__(self)
#    1407     feasible = True
#    1408     cv = np.atleast_2d([0.])
# -> 1409     energy = self.func(parameters)
#    1410     self._nfev += 1
#    1412 # compare trial and population member
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/_lib/_util.py:360, in _FunctionWrapper.__call__(self, x)
#     359 def __call__(self, x):
# --> 360     return self.f(x, *self.args)
#
# Cell In[4], line 11, in obj(x, *args)
#       9 # print(trail_traces[1])
#      10 target_model = de_obj_model(args[1], args[0])
# ---> 11 target_traces = target_model.simulation()
#      12 # print(target_traces[1])
#      14 fit = np.sum(np.square(trail_traces - target_traces))
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:75, in de_obj_model.simulation(self)
#      69 '''
#      70 simulation only contains fixed prestep potential and a number of step potentials, covered in the sim_setup dict
#      71 generate current traces according to the setup
#      72 '''
#      74 # self.current_traces = np.array([self.find_I(v) for v in self.step_Vs])
# ---> 75 self.current_traces = self.find_I(self.step_Vs)
#      77 return self.current_traces
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:66, in de_obj_model.find_I(self, V)
#      65 def find_I(self, V):
# ---> 66     return np.full(self.m(self.step_Vs).shape, self.g_max) * np.power(self.m(V), np.full(self.m(self.step_Vs).shape, self.p)) * (V - np.full(self.m(self.step_Vs).shape, self.E_rev))
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63, in de_obj_model.m(self, V)
#      58 def m(self, V):
#      59     '''
#      60     Find the activation/inactivation variable analytically with I.C. x(0) = initial_cond
#      61     This only stands with fixed prestep potential simulation setup!
#      62     '''
# ---> 63     return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
#
# File /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33, in de_obj_model.m_infty(self, V)
#      29 def m_infty(self, V):
#      30 # Find the steady-state curve at a fixed V, x goes to steady_state as t increses
#      31 # V: membrane voltage
#      32     # V_2m is only defined for steady state and time constant
# ---> 33     return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
#
# KeyboardInterrupt:

# %% [markdown]
# ### Parallization

# %%
import csv
import os
csv_filename = "de_experiment_results_parrallell_4.csv"
# Define the headers for the CSV file
csv_headers = ['Strategy', 'Popsize', 'Mutation', 'Recombination', 'Init', 'MSE Overall Avg', 'MSE Overall Std', 'Elapsed Time Avg', 'Elapsed Time Std']

# Check if the CSV file exists; if not, create and write the headers
if not os.path.exists(csv_filename):
    with open(csv_filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(csv_headers)

# %%
import csv
import time
import numpy as np
from functools import partial
from multiprocessing import Pool
from scipy.optimize import differential_evolution

def process_sample(sample, strategy, popsize, mutation, recombination, init):
    prestep_V_2d = prestep_V_2d_vec[sample]
    step_Vs_2d = step_Vs_2d_vec[sample]
    t = time_traces[sample]
    # target_traces = current_traces[sample]
    target_params = params[sample]

    # sim setup for obj evaluation model
    sim_setup_2d = {'prestep_V': prestep_V_2d, 'step_Vs': step_Vs_2d, 't': t}   

    start_time = time.time()
    result = differential_evolution(obj, bounds, args=(sim_setup_2d, target_params), strategy=strategy, popsize=popsize, mutation=mutation, recombination=recombination, init=init, seed=42, maxiter=2)
    end_time = time.time()
    
    mse = (target_params - result.x) ** 2
    elapsed_time = end_time - start_time
    return sample, mse, elapsed_time

if __name__ == '__main__':
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        pool = Pool()  # Creates a pool of processes
        
        for strategy in hyperparameters_grid['strategy']:
            for popsize in hyperparameters_grid['popsize']:
                for mutation in hyperparameters_grid['mutation']:
                    for recombination in hyperparameters_grid['recombination']:
                        for init in hyperparameters_grid['init']:
                            # Use partial to fix hyperparameters for the current loop iteration
                            process_func = partial(process_sample, strategy=strategy, popsize=popsize, mutation=mutation, recombination=recombination, init=init)
                            
                            # Map the process function to the sample range using the multiprocessing pool
                            results = pool.map(process_func, range(3))

                            mse_list = []
                            time_list = []
                            for result in results:
                                sample, mse, elapsed_time = result
                                mse_list.append(mse)
                                time_list.append(elapsed_time)

                            mse_mat = np.vstack(mse_list)
                            time_mat = np.array(time_list).reshape(-1, 1)

                            mse_overall_avg = np.mean(mse_mat)
                            mse_overall_std = np.std(np.mean(mse_mat, axis=1))
                            time_overall_avg = np.mean(time_mat)
                            time_overall_std = np.std(time_mat)
                            
                            writer.writerow([strategy, popsize, mutation, recombination, init, mse_overall_avg, mse_overall_std, time_overall_avg, time_overall_std])
        
        pool.close()  # Close the pool
        pool.join()   # Wait for all processes to finish before exiting
# Out:
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: invalid value encountered in multiply
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: invalid value encountered in multiply
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:33: RuntimeWarning: overflow encountered in exp
#   return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: overflow encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in log
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: invalid value encountered in multiply
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: invalid value encountered in multiply
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: invalid value encountered in multiply
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in log
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: invalid value encountered in multiply
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:42: RuntimeWarning: invalid value encountered in multiply
#   return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: overflow encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: invalid value encountered in scalar multiply
#   tau_0m = (1 / self.a_m) * np.exp((self.delta_m * self.V_2m) / self.s_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: divide by zero encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:63: RuntimeWarning: invalid value encountered in divide
#   return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:23: RuntimeWarning: divide by zero encountered in scalar divide
#   self.V_2m = - self.s_m * np.log(self.b_m / self.a_m)
# /lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py:41: RuntimeWarning: divide by zero encountered in scalar divide
# ...
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py", line 402, in differential_evolution
#     ret = solver.solve()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/tmp/ipykernel_2467048/1736697382.py", line 19, in process_sample
#     result = differential_evolution(obj, bounds, args=(sim_setup_2d, target_params), strategy=strategy, popsize=popsize, mutation=mutation, recombination=recombination, init=init, seed=42, maxiter=2)
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py", line 402, in differential_evolution
#     ret = solver.solve()
# KeyboardInterrupt
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py", line 1022, in solve
#     next(self)
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py", line 1409, in __next__
#     energy = self.func(parameters)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/_lib/_util.py", line 360, in __call__
#     return self.f(x, *self.args)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py", line 1022, in solve
#     next(self)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/tmp/ipykernel_2467048/2442401016.py", line 8, in obj
#     trail_traces = trail_model.simulation()
# KeyboardInterrupt
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py", line 75, in simulation
#     self.current_traces = self.find_I(self.step_Vs)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/_lib/_util.py", line 360, in __call__
#     return self.f(x, *self.args)
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py", line 42, in tau_m
#     return ((tau_0m * np.exp(self.delta_m * ((V - self.V_2m) / self.s_m))) / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py", line 1388, in __next__
#     trial = self._mutate(candidate)
# KeyboardInterrupt
#   File "/tmp/ipykernel_2467048/1736697382.py", line 19, in process_sample
#     result = differential_evolution(obj, bounds, args=(sim_setup_2d, target_params), strategy=strategy, popsize=popsize, mutation=mutation, recombination=recombination, init=init, seed=42, maxiter=2)
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py", line 1510, in _mutate
#     crossovers = rng.uniform(size=self.parameter_count)
# KeyboardInterrupt
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py", line 66, in find_I
#     return np.full(self.m(self.step_Vs).shape, self.g_max) * np.power(self.m(V), np.full(self.m(self.step_Vs).shape, self.p)) * (V - np.full(self.m(self.step_Vs).shape, self.E_rev))
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py", line 402, in differential_evolution
#     ret = solver.solve()
# KeyboardInterrupt
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py", line 1022, in solve
#     next(self)
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/ENV/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py", line 1409, in __next__
#     energy = self.func(parameters)
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py", line 63, in m
#     return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
#   File "/tmp/ipykernel_2467048/2442401016.py", line 8, in obj
#     trail_traces = trail_model.simulation()
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py", line 75, in simulation
#     self.current_traces = self.find_I(self.step_Vs)
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py", line 66, in find_I
#     return np.full(self.m(self.step_Vs).shape, self.g_max) * np.power(self.m(V), np.full(self.m(self.step_Vs).shape, self.p)) * (V - np.full(self.m(self.step_Vs).shape, self.E_rev))
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py", line 63, in m
#     return self.m_infty(V) + (self.m_infty(self.prestep_V) - self.m_infty(V)) * np.exp(- self.t / self.tau_m(V))
#   File "/lustre06/project/6000803/maxwell8/Compute-Canada-Research/Exp_rates_generalized_exp_setup/DE/DE_obj_model.py", line 33, in m_infty
#     return (1 / (1 + np.exp((V - self.V_2m) / self.s_m))).reshape((-1,1))
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 40
#      37 process_func = partial(process_sample, strategy=strategy, popsize=popsize, mutation=mutation, recombination=recombination, init=init)
#      39 # Map the process function to the sample range using the multiprocessing pool
# ---> 40 results = pool.map(process_func, range(3))
#      42 mse_list = []
#      43 time_list = []
#
# File /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/threading.py:600, in Event.wait(self, timeout)
#     598 signaled = self._flag
#     599 if not signaled:
# --> 600     signaled = self._cond.wait(timeout)
#     601 return signaled
#
# File /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/python/3.10.2/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
np.mean(mse_mat, axis=1).shape
# Out:
# (439,)

# %%
np.mean(mse_mat), np.std(np.mean(mse_mat, axis=1)), np.mean(time_mat), np.std(time_mat)
# Out:
# (511.3364727433909, 417.878264540534, 0.1499422720733156, 0.033234656515269134)

# %%
np.mean(np.mean(mse_mat, axis=0)), np.mean(time_mat, axis=0)
# Out:
# (511.336472743391, array([0.14994227]))

# %%
time_mat.shape, mse_mat.shape
# Out:
# ((439, 1), (439, 7))

# %%
np.hstack((mse_mat, time_array.reshape(-1, 1)))
# Out:
# (220, 8)

# %% [markdown]
# #### Run DE on all test dataset, check result mse on all params here

# %%
mse_mat = np.load('de_mse_params_all_test.npy')

# %%
mse_mat.shape
# Out:
# (30, 7)

# %%
mse_params = np.mean(mse_mat, axis=0)
mse_params
# Out:
# array([1.68353114e-03, 5.70682053e+01, 1.12901201e+02, 2.79381230e-03,
#        7.58826951e+00, 1.83145674e-04, 7.30552287e-02])

# %% [markdown]
# ## Define obj fct and estimate for single param

# %%
def obj_i_param(x, *args): 
    '''
    x: a single float value of the i-th param
    args: a tupleo f additional fixed parameters (prestep_V, step_V0, time_traces)
    *args=(i, sim_setup_2d, target_params)
    '''
    params = args[2].copy()
    params[args[0]] = x
    trail_model = de_obj_model(params, args[1])
    trail_traces = trail_model.simulation()
    # print(trail_traces[1])
    target_model = de_obj_model(args[2], args[1])
    target_traces = target_model.simulation()
    # print(target_traces[1]) 
    
    return np.sum(np.square(trail_traces - target_traces))

# %%
params_searching_bounds = {
    'p': (1, 5),
    'g_max': (100, 140), 
    'E_rev': (-100, -60), 
    'a_m': (0, 13), 
    'b_m': (0, 100), 
    'delta_m': (0, 1), 
    's_m': (-17, -10)
}
i = 6
key_at_index = list(params_searching_bounds.keys())[i]
bounds = [params_searching_bounds[key_at_index]]
bounds
# Out:
# [(-17, -10)]

# %%
from scipy.optimize import differential_evolution
result = differential_evolution(obj_i_param, bounds, args=(i, sim_setup_2d, target_params), maxiter=100)#, tol = 1e-10)
result
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 0.0
#        x: [-1.105e+01]
#      nit: 22
#     nfev: 347

# %%
((target_params[i] - result.x) ** 2)
# Out:
# array([2.0789837e-15])

# %% [markdown]
# #### Results for all single param estimation

# %%
mses = np.load('de_mses_on_ith_params.npy')
nits = np.load('de_nit_on_ith_params.npy')
mses.shape, nits.shape
# Out:
# ((30, 7), (30, 7))

# %%
arr = mses.mean(axis=0)
print(arr)

sorted_indices = np.argsort(arr)

print("Sorted indices:", sorted_indices)
# Out:
# [1.40752475e-15 6.77700377e-15 2.20245039e-15 1.40308669e-15
#  2.14625476e-15 1.44141350e-15 2.20503233e-15]
# Sorted indices: [3 0 5 4 2 6 1]

# %%
arr = nits.mean(axis=0)
print(arr)

sorted_indices = np.argsort(arr)

print("Sorted indices:", sorted_indices)
# Out:
# [27.         26.1        26.53333333 26.53333333 26.83333333 27.23333333
#  26.33333333]
# Sorted indices: [1 6 2 3 4 0 5]
