# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import sys
sys.path.append('..')
from exp_hh_model import HH_model_exp
from dataset_reader import Traces_Dataset

# %%
dataset = Traces_Dataset('../dataset2mil.csv')
parameters = dataset.params.numpy()

# %%
parameters.shape
# Out:
# (2000000, 7)

# %%
# Custom bin boundaries
bin_boundaries = [0.5, 1.5, 2.5, 3.5, 4.5]
count, bins, _ = plt.hist(parameters[:, 0], bins=bin_boundaries, align='mid', rwidth=1)
plt.xlabel('p')
plt.ylabel('count')
# Set x-axis ticks to include only integers 1, 2, 3, and 4
plt.xticks([1, 2, 3, 4])
# Out:
# ([<matplotlib.axis.XTick at 0x14c60ff295a0>,
#   <matplotlib.axis.XTick at 0x14c60ff29570>,
#   <matplotlib.axis.XTick at 0x14c610084d90>,
#   <matplotlib.axis.XTick at 0x14c60ff51f00>],
#  [Text(1, 0, '1'), Text(2, 0, '2'), Text(3, 0, '3'), Text(4, 0, '4')])

# %%
count, bins, _ = plt.hist(parameters[:, 1], bins=100)
plt.xlabel('$\\overline{g}\;(mS/cm^2)$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
count, bins, _ = plt.hist(parameters[:, 2], bins=100)
plt.xlabel('$E_{rev}\;(mV)$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
count, bins, _ = plt.hist(parameters[:, 3], bins=100)
plt.xlabel('$a_n\;(ms^{-1})$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
count, bins, _ = plt.hist(parameters[:, 4], bins=100)
plt.xlabel('$b_n\;(ms^{-1})$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
count, bins, _ = plt.hist(parameters[:, 5], bins=100)
plt.xlabel('$\\delta_n$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
count, bins, _ = plt.hist(parameters[:, 6], bins=100)
plt.xlabel('$s_n\;(mV)$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')
