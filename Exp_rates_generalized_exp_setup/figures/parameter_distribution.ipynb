# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import sys
sys.path.append('..')
from exp_hh_model import HH_model_exp
from dataset_reader import Traces_Dataset

# %%
dataset = Traces_Dataset('../dataset_test.csv')
parameters = dataset.params.numpy()

# %%
parameters.shape
# Out:
# (1000, 7)

# %%
count, bins, _ = plt.hist(parameters[:, 0], bins=100)
plt.xlabel('p')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
count, bins, _ = plt.hist(parameters[:, 1], bins=100)
plt.xlabel('g_{max}')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
count, bins, _ = plt.hist(parameters[:, 2], bins=100)
plt.xlabel('$E_{rev}$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
count, bins, _ = plt.hist(parameters[:, 3], bins=100)
plt.xlabel('$a_m$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
count, bins, _ = plt.hist(parameters[:, 4], bins=100)
plt.xlabel('$b_m$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
count, bins, _ = plt.hist(parameters[:, 5], bins=100)
plt.xlabel('$delta_m$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
count, bins, _ = plt.hist(parameters[:, 6], bins=100)
plt.xlabel('$s_m$')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')
