# %%
import numpy as np
import matplotlib.pyplot as plt
from exp_hh_model import HH_model_exp

# %%
params = {'p': 2, 'g_max': 120, 'E_rev': -90, 'a_m': 4, 'b_m': 48, 'delta_m': 0.5, 's_m': -20}
sim_setup = {'prestep_V': -100, 'step_Vs': np.linspace(0, 100, 11), 't': np.arange(0.0, 6.0, 0.01)}
plot_range = range(int(sim_setup['step_Vs'][0]), int(sim_setup['step_Vs'][-1]))
model = HH_model_exp(params, sim_setup)

# %%
current_traces = model.simulation()
plt.plot(sim_setup['t'], current_traces[10], label = f'{step_Vs[step]}')
plt.xlim(0, 0.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 current_traces = model.simulation()
# ----> 2 plt.plot(sim_setup['t'], current_traces[10], label = f'{step_Vs[step]}')
#       3 plt.xlim(0, 0.4)
#
# NameError: name 'step_Vs' is not defined

# %%
model.tau_m(100)/0.63
# Out:
# 0.03013669843125423

# %%
current_traces = model.simulation()
current_traces.shape
step_Vs = sim_setup['step_Vs']

for step in range(len(step_Vs)): 
    plt.plot(sim_setup['t'], current_traces[step], label = f'{step_Vs[step]}')
    
plt.legend()

# %%
print(model.check_current_ss())
model.max_index_array
# Out:
# True
# /Users/maxwellyue/Documents/GitHub/Compute-Canada-Research/Exponential Rates/exp_hh_model.py:85: RuntimeWarning: divide by zero encountered in divide
#   diff_arr = np.abs((self.current_traces[i, :][1:] - self.current_traces[i, :][:-1]) / (self.current_traces[i, :][:-1] - self.current_traces[i, :][0]))
# array([22, 27, 31, 35, 38, 39, 38, 35, 31, 26, 22])

# %%
plt.plot(model.m(90))

# %%
# get steady state curve/activation curve
plot_range = range(-200, 200)

m_infty_curve = np.array([model.m_infty(V) for V in plot_range])

plt.plot(plot_range, m_infty_curve)

plt.xlabel('Membrane Voltage (mV)')
plt.ylabel('$m_\infty$')
plt.title('Activation Steady State Curve')
# Out:
# Text(0.5, 1.0, 'Activation Steady State Curve')

# %%
model.check_steady_state_curve()
# Out:
# True

# %%
model.V_2m
# Out:
# 49.698132995760005

# %%
# get the time constant curve
time_constant_curve = np.array([model.tau_m(V) for V in plot_range]) / (0.63)

plt.plot(plot_range, time_constant_curve)

plt.xlabel('Membrane Voltage (mV)')
plt.ylabel('$\u03C4_m$')
plt.title('Activation Time Constant Curve')
# Out:
# Text(0.5, 1.0, 'Activation Time Constant Curve')

# %%
opening_rates = np.array([model.alpha(V) for V in plot_range]) 
closing_rates = np.array([model.beta(V) for V in plot_range]) 

plt.plot(plot_range, opening_rates, color='red', label = '\u03B1')
plt.plot(plot_range, closing_rates, color='blue', label = '\u03B2')

plt.xlabel('Membrane Voltage (mV)')
plt.ylabel('$rate$')
plt.legend()
plt.title('Opening and Closing Rate Curves')
# Out:
# Text(0.5, 1.0, 'Opening and Closing Rate Curves')

# %% [markdown]
# #### Here, we use the HH rate functions to infer some bounds on the V_2m, s_m, delta_m, a_m, b_m

# %%
# Hodgkin Huxley rate functions for the potassium currents in the squid giant axon. 
def hh_alpha(V): 
    return 0.1 * (25 - V) / (np.exp((25-V) / 10) - 1)

def hh_beta(V): 
    return 4 * np.exp(-V / 18)

def hh_m_infty(V): 
    return hh_alpha(V) / (hh_alpha(V) + hh_beta(V))

def hh_tau_m(V): 
    return 1 / (hh_alpha(V) + hh_beta(V))

def m(V): 
    hh_m_infty(V) + (hh_m_infty(model.prestep_V) - hh_m_infty(V)) * np.exp(- model.t / hh_tau_m(V))

# %%
# get steady state curve/activation curve
m_infty_curve = np.array([hh_m_infty(V) for V in range(-100, 100)])

plt.plot(range(-100, 100), m_infty_curve)

plt.xlabel('Membrane Voltage (mV)')
plt.ylabel('$m_\infty$')
plt.title('Activation Steady State Curve')
# Out:
# /var/folders/7_/yd2c8wld3sggx9gtmv9ydwm80000gn/T/ipykernel_36460/1539302064.py:3: RuntimeWarning: invalid value encountered in double_scalars
#   return 0.1 * (25 - V) / (np.exp((25-V) / 10) - 1)
# Text(0.5, 1.0, 'Activation Steady State Curve')

# %%
opening_rates = np.array([hh_alpha(V) for V in range(-100, 100)]) 
closing_rates = np.array([hh_beta(V) for V in range(-100, 100)]) 

plt.plot(range(-100, 100), opening_rates, color='red', label = '\u03B1')
plt.plot(range(-100, 100), closing_rates, color='blue', label = '\u03B2')

plt.xlabel('Membrane Voltage (mV)')
plt.ylabel('$rate$')
plt.legend()
plt.title('Opening and Closing Rate Curves')
# Out:
# /var/folders/7_/yd2c8wld3sggx9gtmv9ydwm80000gn/T/ipykernel_36460/3989276616.py:3: RuntimeWarning: invalid value encountered in double_scalars
#   return 0.1 * (25 - V) / (np.exp((25-V) / 10) - 1)
# Text(0.5, 1.0, 'Opening and Closing Rate Curves')
